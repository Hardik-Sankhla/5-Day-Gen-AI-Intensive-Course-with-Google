# %% [markdown]
# # Day 1 — Foundational LLMs & Prompt Engineering
#
# This notebook contains pointers and small examples to get started with prompt engineering and LLM evaluation.

# %%
# Minimal check
print('Hello from Day 1 notebook')
